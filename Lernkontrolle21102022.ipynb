# %% [markdown]
# <center><h1 style="font-size:2em;color:#2467C0;font-family:Times New Roman">LernKontrolle 21.10.2022</h1></center>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#   <hr>
#       <h4 style="font-family:courier;font-size:1.3em">
# Lade die CSV Datein 'Dataset.csv' herunter und speichere sie in einem gewünschten Ordner auf deinem Rechner.
# </h4>
# <hr>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
#           <h4 style="font-family:courier;font-size:1.7em">
# Aufgabe1
# </h4>
#   <hr>
#       <h4 style="font-family:courier;font-size:1.5em">
# Bearbeite die unteren angegebenen Steps<br>
# </h4>
# </div>

# %% [markdown]
# # Step1
# ### Lese die  'dataset.csv' Datei  und speichere den Dataframe in der Variable 'data'. Gib anschließend die ersten 4 Zeilen des Dataframes aus

# %%
import pandas as pd
import numpy as np
import missingno as msno

# %%
data=pd.read_csv("C:/Daten@Server/Python/Tag 39 - 2022-10-21 L - SQL-Einführung/Hausaufgabe/Dataset.csv")
data.head()
# Out:
# C:\Users\mkeil\AppData\Local\Temp\ipykernel_23336\2498088540.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   data=pd.read_csv("C:/Daten@Server/Python/Tag 39 - 2022-10-21 L - SQL-Einführung/Hausaufgabe/Dataset.csv")
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# 1       Geary            St  ...                         3.0
# 2     Pacific            Av  ...                         1.0
# 3     Pacific            Av  ...                         5.0
# 4      Market            St  ...                         3.0
#
#   Existing Construction Type Description Proposed Construction Type  \
# 0                          constr type 3                        NaN
# 1                          constr type 3                        NaN
# 2                          constr type 1                        1.0
# 3                         wood frame (5)                        5.0
# 4                          constr type 3                        NaN
#
#   Proposed Construction Type Description Site Permit Supervisor District  \
# 0                                    NaN         NaN                 3.0
# 1                                    NaN         NaN                 3.0
# 2                          constr type 1         NaN                 3.0
# 3                         wood frame (5)         NaN                 3.0
# 4                                    NaN         NaN                 6.0
#
#   Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                          Tenderloin  94102.0
# 1                          Tenderloin  94102.0
# 2                        Russian Hill  94109.0
# 3                            Nob Hill  94109.0
# 4                          Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 43 columns]

# %%
data.shape
# Out:
# (198900, 43)

# %%
...
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 103865  201510281024            8            otc alterations permit
# 151992  201703131363            8            otc alterations permit
# 92291   201507161675            3  additions alterations or repairs
# 177285  201706169592            8            otc alterations permit
# 72244   201501095369            8            otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 103865           10/28/2015  1238  021            252                  NaN
# 151992           03/13/2017  1182  006           1330                  NaN
# 92291            07/16/2015  6580  018            456                  NaN
# 177285           06/16/2017  6657  063            225                  NaN
# 72244            01/09/2015  3705  042            865                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 103865  Divisadero            St  ...                         5.0
# 151992       Grove            St  ...                         5.0
# 92291         27th            St  ...                         NaN
# 177285        30th            St  ...                         5.0
# 72244       Market            St  ...                         1.0
#
#        Existing Construction Type Description Proposed Construction Type  \
# 103865                         wood frame (5)                        5.0
# 151992                         wood frame (5)                        5.0
# 92291                                     NaN                        5.0
# 177285                         wood frame (5)                        5.0
# 72244                           constr type 1                        1.0
#
#        Proposed Construction Type Description Site Permit Supervisor District  \
# 103865                         wood frame (5)         NaN                 5.0
# 151992                         wood frame (5)         NaN                 5.0
# 92291                          wood frame (5)         NaN                 8.0
# 177285                         wood frame (5)         NaN                 8.0
# 72244                           constr type 1         NaN                 6.0
#
#        Neighborhoods - Analysis Boundaries  Zipcode  \
# 103865                      Haight Ashbury  94117.0
# 151992                        Hayes Valley  94117.0
# 92291                           Noe Valley  94131.0
# 177285                           Glen Park  94131.0
# 72244                      South of Market  94103.0
#
#                                          Location      Record ID
# 103865  (37.771524707639244, -122.43688341032507)  1401070458247
# 151992   (37.77605671059633, -122.43860463626021)   145609491582
# 92291   (37.746929699818665, -122.43050932566561)  1388664208079
# 177285   (37.74184590091654, -122.42504706182866)  1467260210229
# 72244    (37.78394695277329, -122.40715830610168)  1367292164435
#
# [5 rows x 43 columns]

# %% [markdown]
# # Step2
# ## Wie viel NaN hat jeder Spalte!?
# ### Gib anschließend die 10 größten Werte aus

# %%
data.isna().sum().sort_values(ascending=False).head(10)
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %%
...
# Out:
# TIDF Compliance                  198898
# Voluntary Soft-Story Retrofit    198865
# Unit Suffix                      196939
# Street Number Suffix             196684
# Site Permit                      193541
# Structural Notification          191978
# Fire Only Permit                 180073
# Unit                             169421
# Completed Date                   101709
# Permit Expiration Date            51880
# dtype: int64

# %% [markdown]
# # Step 3
# ### Lösche die Spalten wo die Null Werte 50%>

# %%
a = data.isna().sum()/ data.shape[0]
a.sort_values(ascending = True,inplace=True)
data1=data[data.columns[a<0.5]]
data1.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Permit Expiration Date Estimated Cost  \
# 0       Ellis            St  ...              11/03/2016         4000.0
# 1       Geary            St  ...              12/03/2017            1.0
# 2     Pacific            Av  ...                     NaN        20000.0
# 3     Pacific            Av  ...              07/13/2018         2000.0
# 4      Market            St  ...              12/01/2018       100000.0
#
#   Revised Cost         Existing Use Existing Units       Proposed Use  \
# 0       4000.0  tourist hotel/motel          143.0                NaN
# 1        500.0  tourist hotel/motel            NaN                NaN
# 2          NaN         retail sales           39.0       retail sales
# 3       2000.0    1 family dwelling            1.0  1 family dwelling
# 4     100000.0         retail sales            NaN                NaN
#
#   Proposed Units Plansets TIDF Compliance Existing Construction Type
# 0            NaN      2.0             NaN                        3.0
# 1            NaN      2.0             NaN                        3.0
# 2           39.0      2.0             NaN                        1.0
# 3            1.0      2.0             NaN                        5.0
# 4            NaN      2.0             NaN                        3.0
#
# [5 rows x 34 columns]

# %%
...
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Street Suffix  \
# 0           05/06/2015  0326  023            140       Ellis            St
# 1           04/19/2016  0306  007            440       Geary            St
# 2           05/27/2016  0595  203           1647     Pacific            Av
# 3           11/07/2016  0156  011           1230     Pacific            Av
# 4           11/28/2016  0342  001            950      Market            St
#
#                                          Description  ... Plansets  \
# 0  ground fl facade: to erect illuminated, electr...  ...      2.0
# 1            remove (e) awning and associated signs.  ...      2.0
# 2                    installation of separating wall  ...      2.0
# 3           repair dryrot & stucco at front of bldg.  ...      2.0
# 4  demolish retail/office/commercial 3-story buil...  ...      2.0
#
#   Existing Construction Type Existing Construction Type Description  \
# 0                        3.0                          constr type 3
# 1                        3.0                          constr type 3
# 2                        1.0                          constr type 1
# 3                        5.0                         wood frame (5)
# 4                        3.0                          constr type 3
#
#   Proposed Construction Type Proposed Construction Type Description  \
# 0                        NaN                                    NaN
# 1                        NaN                                    NaN
# 2                        1.0                          constr type 1
# 3                        5.0                         wood frame (5)
# 4                        NaN                                    NaN
#
#    Supervisor District  Neighborhoods - Analysis Boundaries  Zipcode  \
# 0                  3.0                           Tenderloin  94102.0
# 1                  3.0                           Tenderloin  94102.0
# 2                  3.0                         Russian Hill  94109.0
# 3                  3.0                             Nob Hill  94109.0
# 4                  6.0                           Tenderloin  94102.0
#
#                                     Location      Record ID
# 0  (37.785719256680785, -122.40852313194863)  1380611233945
# 1   (37.78733980600732, -122.41063199757738)  1420164406718
# 2    (37.7946573324287, -122.42232562979227)  1424856504716
# 3   (37.79595867909168, -122.41557405519474)  1443574295566
# 4   (37.78315261897309, -122.40950883997789)   144548169992
#
# [5 rows x 34 columns]

# %% [markdown]
# # Step 4
# ### Prozentual gesehen, wie viel NaN Werte gibt es im ganzen DataFrame?

# %%
len(data1.isna().count())
# Out:
# 34

# %%
# Anzhal der NaN werte
data1.isna().sum().count()
# Out:
# 34

# %%
a=data1.isna().sum().sum()#Summe aller NaN-Werte
b=data1.shape[0]*data1.shape[1]#summe aller Werte im DataFrame

# %%
a/b*100
# Out:
# 28.330109721113182

# %%
...
# Out:
# 33.21120574926803

# %% [markdown]
# # step 5
# ### Zeige mithilfe der missingno Library alle NaN Werte in einem Graphen an

# %%
msno.matrix(data1)
# Out:
# <AxesSubplot: >

# %%
...

# %% [markdown]
# # Step6 (recherche Aufgabe)
# ## Fülle alle NaN Werte in der Spalte "Existing Use" mit dem nächsten darüber liegenden NICHT NaN Wert!
# ## Im zweiten Schritt, füllt die übrigen NaN Werte mit 0.
# ### Die beiden folgenden Tabellen sind Beispiele zur Veranschaulichung. Die erste zeigt die Ausgangstabelle und die zweite das Ergebnis nach Anwendung des zweiten Schrittes.

# %% [markdown]
# Spalte 1 | Spalte 2
# -------- | --------
# NaN   | 1
#  3  | NaN
# NaN | 7
# NaN   | NaN

# %% [markdown]
# ##### Endergebnis
# Spalte 1 | Spalte 2
# -------- | --------
# 0   | 1
#  3  | 1
# 3 | 7
# 3   | 7

# %%
data1["Existing Use"].fillna(method="ffill",inplace=True)
# Out:
# C:\Users\mkeil\AppData\Local\Temp\ipykernel_23336\328234424.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Existing Use"].fillna(method="ffill",inplace=True)

# %%
data1.fillna(0,inplace=True)
# Out:
# C:\Users\mkeil\AppData\Local\Temp\ipykernel_23336\4122726797.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.fillna(0,inplace=True)

# %%
data1.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                    0
# 1           04/19/2016  0306  007            440                    0
# 2           05/27/2016  0595  203           1647                    0
# 3           11/07/2016  0156  011           1230                    0
# 4           11/28/2016  0342  001            950                    0
#
#   Street Name Street Suffix  ...  Permit Expiration Date Estimated Cost  \
# 0       Ellis            St  ...              11/03/2016         4000.0
# 1       Geary            St  ...              12/03/2017            1.0
# 2     Pacific            Av  ...                       0        20000.0
# 3     Pacific            Av  ...              07/13/2018         2000.0
# 4      Market            St  ...              12/01/2018       100000.0
#
#   Revised Cost         Existing Use Existing Units       Proposed Use  \
# 0       4000.0  tourist hotel/motel          143.0                  0
# 1        500.0  tourist hotel/motel            0.0                  0
# 2          0.0         retail sales           39.0       retail sales
# 3       2000.0    1 family dwelling            1.0  1 family dwelling
# 4     100000.0         retail sales            0.0                  0
#
#   Proposed Units Plansets TIDF Compliance Existing Construction Type
# 0            0.0      2.0               0                        3.0
# 1            0.0      2.0               0                        3.0
# 2           39.0      2.0               0                        1.0
# 3            1.0      2.0               0                        5.0
# 4            0.0      2.0               0                        3.0
#
# [5 rows x 34 columns]

# %% [markdown]
# # Step 7
# ## Ersetze die NaN Werte in der Spalte "Number of Existing Stories"  mit einer 1

# %%
data1["Number of Existing Stories"]=data1["Number of Existing Stories"].fillna(1)
data1
# Out:
# C:\Users\mkeil\AppData\Local\Temp\ipykernel_23336\1408109652.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Number of Existing Stories"]=data1["Number of Existing Stories"].fillna(1)
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326   023            140                    0
# 1                04/19/2016  0306   007            440                    0
# 2                05/27/2016  0595   203           1647                    0
# 3                11/07/2016  0156   011           1230                    0
# 4                11/28/2016  0342   001            950                    0
# ...                     ...   ...   ...            ...                  ...
# 198895           12/05/2017  0113  017A           1228                    0
# 198896           12/05/2017  0271   014            580                    0
# 198897           12/06/2017  4318   019           1568                    0
# 198898           12/06/2017  0298   029            795                    0
# 198899           12/07/2017  0160   006            838                    0
#
#        Street Name Street Suffix  ...  Permit Expiration Date Estimated Cost  \
# 0            Ellis            St  ...              11/03/2016         4000.0
# 1            Geary            St  ...              12/03/2017            1.0
# 2          Pacific            Av  ...                       0        20000.0
# 3          Pacific            Av  ...              07/13/2018         2000.0
# 4           Market            St  ...              12/01/2018       100000.0
# ...            ...           ...  ...                     ...            ...
# 198895  Montgomery            St  ...                       0            0.0
# 198896        Bush            St  ...              04/06/2018         5000.0
# 198897     Indiana            St  ...                       0            0.0
# 198898      Sutter            St  ...                       0            0.0
# 198899     Pacific            Av  ...                       0            0.0
#
#        Revised Cost         Existing Use Existing Units       Proposed Use  \
# 0            4000.0  tourist hotel/motel          143.0                  0
# 1             500.0  tourist hotel/motel            0.0                  0
# 2               0.0         retail sales           39.0       retail sales
# 3            2000.0    1 family dwelling            1.0  1 family dwelling
# 4          100000.0         retail sales            0.0                  0
# ...             ...                  ...            ...                ...
# 198895          1.0    2 family dwelling            0.0                  0
# 198896       5000.0           apartments            4.0         apartments
# 198897          1.0           apartments            0.0                  0
# 198898          1.0           apartments            0.0                  0
# 198899          1.0           apartments            0.0                  0
#
#        Proposed Units Plansets TIDF Compliance Existing Construction Type
# 0                 0.0      2.0               0                        3.0
# 1                 0.0      2.0               0                        3.0
# 2                39.0      2.0               0                        1.0
# 3                 1.0      2.0               0                        5.0
# 4                 0.0      2.0               0                        3.0
# ...               ...      ...             ...                        ...
# 198895            0.0      0.0               0                        0.0
# 198896            4.0      2.0               0                        5.0
# 198897            0.0      0.0               0                        0.0
# 198898            0.0      0.0               0                        0.0
# 198899            0.0      0.0               0                        0.0
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 8
# ## Ersetze die NaN Werte in der Spalte "Existing Units"  mit der Maximale Wert Diese Spalte

# %%
data1["Existing Units"]=data1["Existing Units"].fillna(np.nanmax(data1["Existing Units"]))
data1
# Out:
# C:\Users\mkeil\AppData\Local\Temp\ipykernel_23336\1056391197.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1["Existing Units"]=data1["Existing Units"].fillna(np.nanmax(data1["Existing Units"]))
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326   023            140                    0
# 1                04/19/2016  0306   007            440                    0
# 2                05/27/2016  0595   203           1647                    0
# 3                11/07/2016  0156   011           1230                    0
# 4                11/28/2016  0342   001            950                    0
# ...                     ...   ...   ...            ...                  ...
# 198895           12/05/2017  0113  017A           1228                    0
# 198896           12/05/2017  0271   014            580                    0
# 198897           12/06/2017  4318   019           1568                    0
# 198898           12/06/2017  0298   029            795                    0
# 198899           12/07/2017  0160   006            838                    0
#
#        Street Name Street Suffix  ...  Permit Expiration Date Estimated Cost  \
# 0            Ellis            St  ...              11/03/2016         4000.0
# 1            Geary            St  ...              12/03/2017            1.0
# 2          Pacific            Av  ...                       0        20000.0
# 3          Pacific            Av  ...              07/13/2018         2000.0
# 4           Market            St  ...              12/01/2018       100000.0
# ...            ...           ...  ...                     ...            ...
# 198895  Montgomery            St  ...                       0            0.0
# 198896        Bush            St  ...              04/06/2018         5000.0
# 198897     Indiana            St  ...                       0            0.0
# 198898      Sutter            St  ...                       0            0.0
# 198899     Pacific            Av  ...                       0            0.0
#
#        Revised Cost         Existing Use Existing Units       Proposed Use  \
# 0            4000.0  tourist hotel/motel          143.0                  0
# 1             500.0  tourist hotel/motel            0.0                  0
# 2               0.0         retail sales           39.0       retail sales
# 3            2000.0    1 family dwelling            1.0  1 family dwelling
# 4          100000.0         retail sales            0.0                  0
# ...             ...                  ...            ...                ...
# 198895          1.0    2 family dwelling            0.0                  0
# 198896       5000.0           apartments            4.0         apartments
# 198897          1.0           apartments            0.0                  0
# 198898          1.0           apartments            0.0                  0
# 198899          1.0           apartments            0.0                  0
#
#        Proposed Units Plansets TIDF Compliance Existing Construction Type
# 0                 0.0      2.0               0                        3.0
# 1                 0.0      2.0               0                        3.0
# 2                39.0      2.0               0                        1.0
# 3                 1.0      2.0               0                        5.0
# 4                 0.0      2.0               0                        3.0
# ...               ...      ...             ...                        ...
# 198895            0.0      0.0               0                        0.0
# 198896            4.0      2.0               0                        5.0
# 198897            0.0      0.0               0                        0.0
# 198898            0.0      0.0               0                        0.0
# 198899            0.0      0.0               0                        0.0
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 9
# ## Ersetze die NaN Werte in der Spalte "Plansets"  mit eine Polynomial Interpolation  zweite Ordnung

# %%
data1["Plansets"].interpolate(method ='polynomial',order=2)
data1
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326   023            140                    0
# 1                04/19/2016  0306   007            440                    0
# 2                05/27/2016  0595   203           1647                    0
# 3                11/07/2016  0156   011           1230                    0
# 4                11/28/2016  0342   001            950                    0
# ...                     ...   ...   ...            ...                  ...
# 198895           12/05/2017  0113  017A           1228                    0
# 198896           12/05/2017  0271   014            580                    0
# 198897           12/06/2017  4318   019           1568                    0
# 198898           12/06/2017  0298   029            795                    0
# 198899           12/07/2017  0160   006            838                    0
#
#        Street Name Street Suffix  ...  Permit Expiration Date Estimated Cost  \
# 0            Ellis            St  ...              11/03/2016         4000.0
# 1            Geary            St  ...              12/03/2017            1.0
# 2          Pacific            Av  ...                       0        20000.0
# 3          Pacific            Av  ...              07/13/2018         2000.0
# 4           Market            St  ...              12/01/2018       100000.0
# ...            ...           ...  ...                     ...            ...
# 198895  Montgomery            St  ...                       0            0.0
# 198896        Bush            St  ...              04/06/2018         5000.0
# 198897     Indiana            St  ...                       0            0.0
# 198898      Sutter            St  ...                       0            0.0
# 198899     Pacific            Av  ...                       0            0.0
#
#        Revised Cost         Existing Use Existing Units       Proposed Use  \
# 0            4000.0  tourist hotel/motel          143.0                  0
# 1             500.0  tourist hotel/motel            0.0                  0
# 2               0.0         retail sales           39.0       retail sales
# 3            2000.0    1 family dwelling            1.0  1 family dwelling
# 4          100000.0         retail sales            0.0                  0
# ...             ...                  ...            ...                ...
# 198895          1.0    2 family dwelling            0.0                  0
# 198896       5000.0           apartments            4.0         apartments
# 198897          1.0           apartments            0.0                  0
# 198898          1.0           apartments            0.0                  0
# 198899          1.0           apartments            0.0                  0
#
#        Proposed Units Plansets TIDF Compliance Existing Construction Type
# 0                 0.0      2.0               0                        3.0
# 1                 0.0      2.0               0                        3.0
# 2                39.0      2.0               0                        1.0
# 3                 1.0      2.0               0                        5.0
# 4                 0.0      2.0               0                        3.0
# ...               ...      ...             ...                        ...
# 198895            0.0      0.0               0                        0.0
# 198896            4.0      2.0               0                        5.0
# 198897            0.0      0.0               0                        0.0
# 198898            0.0      0.0               0                        0.0
# 198899            0.0      0.0               0                        0.0
#
# [198900 rows x 34 columns]

# %% [markdown]
# # Step 10
# ### Lade die Aktualisierte Notebook Auf den Server (Github)

# %% [markdown]
# # GOOD LUCK !!!!!

# %%
#Danke
